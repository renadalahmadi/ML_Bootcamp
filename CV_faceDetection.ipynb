# %% [markdown]
# <a href="https://colab.research.google.com/github/renadalahmadi/ML_Bootcamp/blob/main/CV_faceDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread("path image")
cascPath = "path"

# Create the haar cascade
#  class to detect objects
faceCascade = cv2.CascadeClassifier(cascPath)

# Read the image
gray = image

# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
    )
print(faces)

print("The Result: Found {0} faces".format(len(faces)))
print()
# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(gray, (x, y), (x+w, y+h), (255, 0,0), 4)
cv2_imshow(gray)
# Out:
# [[ 56  55  75  75]
#  [168  70  66  66]
#  [267  69  87  87]
#  [354  78  74  74]]
# The Result: Found 4 faces
# <PIL.Image.Image image mode=RGB size=500x426 at 0x7F6081214AD0>
