# %% [markdown]
# <a href="https://colab.research.google.com/github/renadalahmadi/ML_Bootcamp/blob/main/Assignment_I_Pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data 1: Breast Cancer Data Set [1]
#
# **Breast cancer**: is cancer that forms in the cells of the breasts.
# After skin cancer, breast cancer is the most common cancer diagnosed in women in the United States. Breast cancer can occur in both men and women, but it's far more common in women.
#
# **Data** **Set Information:**
# - This is one of three domains provided by the Oncology Institute that has repeatedly appeared in the machine learning literature.
#
# - It includes 201 instances of one class and 85 instances of another class. The instances are described by 9 attributes, some of which are linear and some are nominal.
#
# ![images (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Step 1: Importing Data using Pandas

# %%
# importing Pandas 
import pandas as pd

# Defining Data Path:
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer/breast-cancer.data"

# Reading a Dataset and Adding header (Attributes):
rData = pd.read_csv(url , names = ["Class" , "Age", "Menopause", "Tumor-size", "Inv-nodes", "Node-caps" ,"Deg-malig" , "Breast", "Breast-quad", "Irradiat"]) 

rData.head()
# Out:
#                   Class    Age Menopause Tumor-size Inv-nodes Node-caps  \
# 0  no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3  no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4  no-recurrence-events  40-49   premeno        0-4       0-2        no
#
#    Deg-malig Breast Breast-quad Irradiat
# 0          3   left    left_low       no
# 1          2  right    right_up       no
# 2          2   left    left_low       no
# 3          2  right     left_up       no
# 4          2  right   right_low       no

# %% [markdown]
# Step 2: Understanding Dataset

# %% [markdown]
# **The dataset consists of:**
#
# - 286 Instances
# - 2 classes: no-recurrence-events, recurrence-events
# - 9 features: Class , Age, Menopause, Tumor-size, Inv-nodes, Node-caps , Deg-malig , Breast, Breast-quad, Irradiat.

# %% [markdown]
# #First column: 'Class'
#
# - Data type: Nominal data (Python - Object)
# -  It has binary values either 'no-recurrence-events' or  'recurrence-events'.
# - In order to get faster understanding we can convert categorical data to numerical to apply the sum operation to identify which class is the commonest (reduce the risk of breast cancer).

# %%
rData['Class'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# #Second column: 'Age'
#
# -  Data type: Numerical data (Python - Object)
# - It has 9 groups each one of these group of patients is focsuing on different age range starting from
# 10-19, till 90-99.
# - Perhaps the Ages are arranges as age groups for the sake of clustring, summarization, and simplicty.

# %%
rData['Age'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# #Third column: 'Menopause'
#
# - Data type: Nominal data (Python - Object).
# - The period in woman's life when menstruation ceases.
# - It has 3 categories lt40, ge40, and premeno.

# %%
rData['Menopause'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# #Fourth column: 'Tumor-size'
#
# - Data type: Numerical data (Python - Object).
# - patient's tumer-size on their breast.
# - It ranges from 0-59 divid into 12 categories based on the size.

# %%
rData['Tumor-size'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# #Fifth column: 'Inv-nodes'
#
# - Data type: Numerical data (Python - Object).
# - Node size in main portion of the breast.
# - It ranges from 0-39.

# %%
rData['Inv-nodes'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# #Sixth column: 'Node-caps'
#
# - Data type: Boolean data (Python - Object).
# - Node is present or not in cap of breast.
# - It is either the patient has Node-caps or not

# %%
rData['Node-caps'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# #Seventh column: 'Deg-malig'
#
# - Data type: Numerical data (Python - int64).
# - Stage of breast cancer
# - It has three stages 1,2, and 3.

# %%
rData['Deg-malig'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# #Eighth column: 'Breast'
#
# - Data type: Nominal data (Python - Object).
# - Left or Right breast.

# %%
rData['Breast'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# #Ninth column: 'Breast-quad'
#
# - Data type: Nominal data (Python - Object).
# - the place of tumor, left-up, left-low, right-up, right-low, central.

# %%
rData['Breast-quad'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# #Tenth column: 'Irradiat'
#
# - Data type: Boolean data (Python - Object).
# - Present or not (Yes/ No?)

# %%
rData['Irradiat'].dtypes

# %% [markdown]
# # Dataset 2: Iris Data Set [2]
#
# **Iris Flower:**
#
# Iris is the family in the flower which contains the several species such as the iris.setosa,iris.versicolor,iris.virginica,etc.
#
# **Data** **Set Information:**
# - The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant. One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
#
# - This is an exceedingly simple domain. However, it's used to Predicte class of iris plant using these attributes.
# ![1_nfK3vGZkTa4GrO7yWpcS-Q.png](data:image/png;base64,...)

# %% [markdown]
# Step 1: Importing Data using Pandas

# %%
# importing Pandas 
import pandas as pd

# Defining Data Path:
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Reading a Dataset and Adding header (Attributes):
rData = pd.read_csv(url , names = ["sepal length in cm" , "sepal width in cm", "petal length in cm", "petal width in cm", "class"]) 

rData.head()
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal width in cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %% [markdown]
# Step 2: Understanding Dataset

# %% [markdown]
# **The dataset consists of:**
#
# - 150 Instances
# - 3 labels: species of Iris (Iris setosa, Iris virginica and Iris versicolor)
# - 4 features:
#    1.   Sepal length
#    2.   Sepal width
#    3.   Petal length
#    4.   Sepal width

# %% [markdown]
# #First & Second columns: 'sepal length, width in cm'
# #Third & Fourth columns: 'petal length, width in cm'
#
#
# - Data type: Numerical data (Python - float64).
# - In the shown figure below we can see the difference  between the sepal and petal parts of Iris flower
#
# ![0_7H_gF1KnslexnJ3s.png](data:image/png;base64,...)

# %%
rData['sepal length in cm'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# # Data 1: Teaching Assistant Evaluation Data Set [3]
#
#
# **Breast cancer**: is cancer that forms in the cells of the breasts.
# After skin cancer, breast cancer is the most common cancer diagnosed in women in the United States. Breast cancer can occur in both men and women, but it's far more common in women.
#
# **Data** **Set Information:**
# - The data consist of evaluations of teaching performance over three regular semesters and two summer semesters of 151 teaching assistant (TA) assignments at the Statistics Department of the University of Wisconsin-Madison. The scores were divided into 3 roughly equal-sized categories ("low", "medium", and "high") to form the class variable.
#
#
# ![Early-Years-and-Key-Stage-1-2-Teaching-Assistant.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Step 2: Understanding Dataset

# %% [markdown]
# **The dataset consists of:**
#
# - 151 Instances
# - 3 categoriesls: "low", "medium", and "high"
# - 5 features:
#   1. Native English speaker
#   2. Course instructor
#   3. Course
#   4. Summer or regular semester
#   5. Class size
#   6. Class

# %%
# importing Pandas 
import pandas as pd

# Defining Data Path:
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/tae/tae.data"

# Reading a Dataset and Adding header (Attributes):
rData = pd.read_csv(url , names = ["Native speaker" , "Course Instructor", "Course", "Summer/Regular", "Class size", "Class"]) 

rData.head()
# Out:
#    Native speaker  Course Instructor  Course  Summer/Regular  Class size  \
# 0               1                 23       3               1          19
# 1               2                 15       3               1          17
# 2               1                 23       3               2          49
# 3               1                  5       2               2          33
# 4               2                  7      11               2          55
#
#    Class
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3

# %% [markdown]
# #First column: 'Native English Speaker'
#
# -  Data type: Numerical data (Python - int64)
# -  1 inducaties English speaker, 2 for non-English speaker

# %%
rData['Native speaker'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# #Second column: 'Course Instructor'
#
# -  Data type: Numerical data (Python - int64)
# -  categoricized into 25 categories

# %%
rData['Course Instructor'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# #Third column: 'Course'
#
# -  Data type: Numerical data (Python - int64)
# -  categoricized into 26 categories

# %%
rData['Course'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# #Fourth column: 'Summer/Regular'
#
# -  Data type: Numerical data (Python - int64)
# -  1 inducaties Summer semster, 2 for Regular semester

# %%
rData['Summer/Regular'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# #Fifth column: 'Class size'
#
# -  Data type: Numerical data (Python - int64)
# -  Inducaties the class size in in one course.

# %%
rData['class size'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# #sixth column: 'class'
#
# -  Data type: Numerical data (Python - int64)
# -  The classes classified as 1=Low, 2=Medium, 3=High.

# %%
rData['Class'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# **Resoures**
#
# [1]https://archive.ics.uci.edu/ml/datasets/Breast+Cancer
#
# [2]https://archive.ics.uci.edu/ml/datasets/iris
#
# [3]https://archive.ics.uci.edu/ml/datasets/Teaching+Assistant+Evaluation
